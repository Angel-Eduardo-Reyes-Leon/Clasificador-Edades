# %% [markdown]
# # Exploración del dataset y modelos
#
# Notebook libre para explorar datos, probar ideas, generar visualizaciones para el reporte.

# %%
import pandas as pd
import matplotlib.pyplot as plt

manifest = pd.read_csv('../data/final/manifest.csv')
print(f'Total: {len(manifest):,}')
print(manifest['split'].value_counts())
print(manifest['age_bucket'].value_counts())
